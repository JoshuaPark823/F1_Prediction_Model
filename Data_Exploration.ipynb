# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
race_results = pd.read_csv('./Data/2022_Race_Results.csv')
race_results.head(20)
# Out:
#       Track Position  No            Driver                          Team  \
# 0   Bahrain        1  16   Charles Leclerc                       Ferrari
# 1   Bahrain        2  55      Carlos Sainz                       Ferrari
# 2   Bahrain        3  44    Lewis Hamilton                      Mercedes
# 3   Bahrain        4  63    George Russell                      Mercedes
# 4   Bahrain        5  20   Kevin Magnussen                  Haas Ferrari
# 5   Bahrain        6  77   Valtteri Bottas            Alfa Romeo Ferrari
# 6   Bahrain        7  31      Esteban Ocon                Alpine Renault
# 7   Bahrain        8  22      Yuki Tsunoda               AlphaTauri RBPT
# 8   Bahrain        9  14   Fernando Alonso                Alpine Renault
# 9   Bahrain       10  24       Guanyu Zhou            Alfa Romeo Ferrari
# 10  Bahrain       11  47   Mick Schumacher                  Haas Ferrari
# 11  Bahrain       12  18      Lance Stroll  Aston Martin Aramco Mercedes
# ...

# %%
quali_results = pd.read_csv('./Data/2022_Qualifying_Results.csv')
quali_results.head()
# Out:
#      Track Position  No           Driver                  Team        Q1  \
# 0  Bahrain        1  16  Charles Leclerc               Ferrari  1:31.471
# 1  Bahrain        2   1   Max Verstappen  Red Bull Racing RBPT  1:31.785
# 2  Bahrain        3  55     Carlos Sainz               Ferrari  1:31.567
# 3  Bahrain        4  11     Sergio Perez  Red Bull Racing RBPT  1:32.311
# 4  Bahrain        5  44   Lewis Hamilton              Mercedes  1:32.285
#
#          Q2        Q3  Laps
# 0  1:30.932  1:30.558    15
# 1  1:30.757  1:30.681    14
# 2  1:30.787  1:30.687    15
# 3  1:31.008  1:30.921    18
# 4  1:31.048  1:31.238    17

# %%
sprint_results = pd.read_csv('./Data/2022_Sprint_Results.csv')
sprint_results.head()
# Out:
#             Track Position  No           Driver                  Team  \
# 0  Emilia Romagna        1   1   Max Verstappen  Red Bull Racing RBPT
# 1  Emilia Romagna        2  16  Charles Leclerc               Ferrari
# 2  Emilia Romagna        3  11     Sergio Perez  Red Bull Racing RBPT
# 3  Emilia Romagna        4  55     Carlos Sainz               Ferrari
# 4  Emilia Romagna        5   4     Lando Norris      McLaren Mercedes
#
#    Starting Grid  Laps Time/Retired  Points
# 0              1    21    30:39.567       8
# 1              2    21       +2.975       7
# 2              7    21       +4.721       6
# 3             10    21      +17.578       5
# 4              3    21      +24.561       4

# %%
race_results.shape
quali_results.shape
sprint_results.shape
# Out:
# (40, 9)

# %%
sns.pairplot(race_results)
plt.show()

# %%
sns.pairplot(sprint_results)
plt.show()

# %%
sns.pairplot(quali_results)
plt.show()

# %%
if 'No' in race_results.columns:
    race_results.drop('No', axis=1, inplace=True)

sns.catplot(y="Starting Grid", x="Track", hue="Driver", data=race_results)
plt.show()
